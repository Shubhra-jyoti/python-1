# %%
s="hdu"
# s[0.0]#typeerror
# l=[1]      l[2] will give indexerror
s=["jhdcfj"]
# s.upper() attributeerror
# f=open("shubhra.txt") file notfound error
# import vha ModuleNotFoundError

# %%
def f():
    try:
        print(2)
    finally:
        print(3)
# Out:
# 2
# 3

# %%
try:
    f=open("vha.txt")
    print("hi")
except:
    print("file not found bhai")
# Out:
# file not found bhai

# %%
try:
    f=open("vha.txt","w")
    print(hi)
except Exception as e:
    print(e)
# Out:
# name 'hi' is not defined

# %%
try:
    f=open("vha.txt")
    print(hi)
except FileNotFoundError as f:
    print("file not found")
except Exception as e:
    print(e.with_traceback)
# Out:
# <built-in method with_traceback of NameError object at 0x000002AA148F2180>

# %%
try:
    s={1:2}
    print(x)
# except Exception as e: except block should be at end
    print("sorry try again")    
except FileNotFoundError as f:
    print("file not found")
except NameError as n:
    print("name not defined")
print("b1 is best")
# Out:
# name not defined
# b1 is best

# %%
# try--->error--->except--->finally
# try--->no error--->else--->finally
try:
    f=open("vha1.txt")
except:
    print("sorry")
else:
    print("connection succesfull")
finally:
    f.close()
    print("connection successfully closed")
# Out:
# sorry
# connection successfully closed

# %%
def f():
    try:
        print(1)
    finally:
        print(2)
# Out:
# 1
# 2
# None

# %%
def f():
    try:
        return(1)
    finally:
        return(2)
print(f())

# %%
def f():
    try:
        print("vha")
        return(1)
    finally:
        print(10)
        return(2)
print(f())
# Out:
# vha
# 10
# 2

# %%
raise NameError("variable not defined properly")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-eb3f181e7d15> in <module>
# ----> 1 raise NameError("variable not defined properly")
#
# NameError: variable not defined properly

# %%
try:
    name=input("Enter name")
    value=int(input("Enter value "))
    if (value!=10):
        raise Exception("only 10")
    print("value")
except Exception as e:
    print(e)
# Out:
# Enter namegr;lje
# Enter value 455
# only 10

# %%
class jyoti(Exception):
    def __init__(self,message):
        pass

# %%
try:
    balance=float(input("Enter balance"))
    withdraw=float(input("Enter withdraw amount"))
    if(balance<0 or withdraw<0):
        raise jyoti("value cannot be negative")
    elif(withdraw>balance):
        raise Exception("insufficient balance")

except Exception as e:
    print(e.with_traceback)
else:
    print("transaction succesfull")  
finally:
    print("thank you")
# Out:
# Enter balance-4545
# Enter withdraw amount5356
# <built-in method with_traceback of jyoti object at 0x000002AA1357E100>
# thank you
