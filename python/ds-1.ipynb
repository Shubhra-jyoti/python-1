# %%
s="b1 is best"
print(type(s))
print(id(s))#memory location
print(s[0])
print(s[::-1])
print(s[0::2])
print(s[3:5])
print(s[3])
print(id(s[0]))
print(id(s[1]))
print(s[-7])# negative indexing start from - from right -1\
print(s[0::]) #string slicing access a part of string exclude end index

print(s[1:4])
print(s[9:5:-1])
# Out:
# <class 'str'>
# 1483052378224
# b
# tseb si 1b
# b sbs
# is
# i
# 1482979345136
# 1482979153136
# i
# b1 is best
# 1 i
# tseb

# %%
str=input("Enter a string to check:")
p=str[::-1]
if(p==str):
    print("palindrome")
else:
    print("not a palindrome")
# Out:
# Enter a string to check:dfje
# not a palindrome

# %%
s="VHA-10"
print(id(s))
print(s)
s=s[0:3]+":"+s[4:] 
print(s)
print(id(s))
del(s)
#print(s)# s variable does not exist amnymore
s="hello"
print(s[-11])
# Out:
# 1483052728688
# VHA-10
# VHA:10
# 1483052728432
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-f877456b692b> in <module>
#       8 #print(s)# s variable does not exist amnymore
#       9 s="hello"
# ---> 10 print(s[-11])
#
# IndexError: string index out of range

# %%
# string operations
a="vishal"
b="10"
print(a+b)
print(a*10)

"v" in 'vishal'
"1" in ["1",2,3]
# Out:
# vishal10
# vishalvishalvishalvishalvishalvishalvishalvishalvishalvishal
# True

# %%
# enhanced for loop
s="welcome" #i will have each character of the string
# for i in s:
#     print(i)
for i in("hello"[::2])  :
    print(i)
# count=0
# for i in s:
#     print(i,":",count)
#     count+=1

for index,char in enumerate(s):
    print(index,":",char)
    
for i in enumerate(s):
    print(i)
    
# check if all characters of each string is present in the other
s1=input("Enter string 1")
s2=input("Enter string 2")
isbal=True
for i in s1:
    if(i not in s2):
        isbal=False
        break
for i in s2:
    if (i not in s1):
        isbal=False
        break
if(isbal):
    print("balanced string")
else:
    print("unbalanced string")
# Out:
# h
# l
# o
# 0 : w
# 1 : e
# 2 : l
# 3 : c
# 4 : o
# 5 : m
# 6 : e
# (0, 'w')
# (1, 'e')
# (2, 'l')
# (3, 'c')
# (4, 'o')
# (5, 'm')
# (6, 'e')
# Enter string 1fmgjkleif
# Enter string 2gnfrhjebgfrug
# unbalanced string

# %%
str=input("Enter your string")
start=0
end=5
print(str[start:end])
while True:
    ch=input("do you want another 5")
    if(ch=="yes"):
        start+=5
        end+=5
        if(str[start:end]==""):
            print("No more")
            break
        else:
             print(str[start:end])
        
    else:
        break
# Out:
# Enter your stringdfewef
# dfewe
# do you want another 5no

# %%
s="welcome"
# inbuilt functions
print(len(s))
print(min(s))
print(max(s))
print(sorted(s))
# Out:
# 7
# c
# w
# ['c', 'e', 'e', 'l', 'm', 'o', 'w']

# %%
# capitalize title swapcase upper lower count find rfind index rindex startswith endswith isalnum isupper isspace istitle isdigit isnumeric isidentifier replace join split translate maketrans
import string
dir(string)
s="b1 is best"
print(dir(s))
print(s.capitalize())
print(s)
print(s.title())
print(s.swapcase())
print(s.upper())
print(s.lower())
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
# B1 is best
# b1 is best
# B1 Is Best
# B1 IS BEST
# B1 IS BEST
# ...

# %%
s=input("Enter string")
s=s.title()[:-1]+s[-1].upper()
counter=0
for i in s:
    if(i.isspace()):
        break
    counter+=1 
counter-=1    
s=s[:counter]+s[counter].upper()+s[counter+1:]    
print(s)
# Out:
# Enter stringflfgjojg
# FlfgjojG

# %%
s="apple mango banana apple mango mango"
# s.count("apple",1,len(s))#1
# s.count("eggplant")
print(s.find("a"))
print(s.find("apple",1))
print(s.find("z"))
print(s.rfind("apple"))
print(s.rfind("a",33))
# index is almost the same except for -1 it will give error if the passedes value is not present in the string
print(s.index("a"))
print(s.rindex("a"))
s="b1 is best"
print(s.startswith("b"))
print(s.endswith("was best"))
s="10"
print(s.isalnum())
s="vha 10"
print(s.isalnum())
s="VH1"
print(s.isupper())
s=" "
print(s.isspace())
chr(1)
# Out:
# 0
# 19
# -1
# 19
# -1
# 0
# 32
# True
# False
# True
# False
# True
# True
# '\x01'

# %%
s[33:]
# Out:
# 'ngo'

# %%
print("1h1".isidentifier())
# Out:
# False

# %%
ord("V")
# Out:
# 86

# %%
password=input("Entewr your password:")
containsalnuum=True
containsupper=True
uppercount=0
lowercount=0
digitct=0
containsdigit=True
specialcount=0
containslower=True
containsspecial=True
containsnospace=True
sizematch=True

if(len(password)<8):
    sizmatch=False
    
for i in password:
    if(i.isupper()):
        uppercount+=1
    if(i.islower()):
        lowercount+=1
    if(not(i.isalnum())):
        specialcount+=1
    if(i.isspace()):
        containsnospace=False
    if(i.isdigit()):
        digitct+=1
if(digitct<2):
    containsdigit=False
    
        
        
if(uppercount<2 ):
    containsupper=False
if(lowercount<2):
    containslower=False
if(specialcount<2):
    containsspecial=False

if(not containsspecial):
    print("Password should have atleast two special characters")
if(not containsupper):
    print("Password should have atleast two uppercase characters")
if(not containslower):
    print("Password should have atleast two lowercase characters")
if(not containsnospace):
    print("password cannot have space")
if(not containsdigit):
    print("password must have atleadst two digit")
if(not sizematch):
    print("Length of the password should be grrater than 8")
# Out:
# Entewr your password:ewrtyuiopp[2356@#
# Password should have atleast two uppercase characters

# %%
#encryption or decryption
message=input("Enter in message")
n=int(input("Enter what key you want  2 3 5:"))
encryptmessage=""
for i in message:
    ordv=ord(i)
    ordv=ordv+n
    if(ordv>57 and ordv<65):
        ordv=ordv-10
    elif(ordv>90 and ordv<97):
        ordv=ordv-26
    elif(ordv>122 and not i.isspace()):
        ordv=ordv-26
    elif(i.isspace()):
        ordv=32
        
    char=chr(ordv)
    encryptmessage=encryptmessage+char
print(encryptmessage)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-05dac220a1d9> in <module>
#       1 #encryption or decryption
# ----> 2 message=input("Enter in message")
#       3 n=int(input("Enter what key you want  2 3 5:"))
#       4 encryptmessage=""
#       5 for i in message:
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
# ...

# %%
#decryption
original=""
for i in encryptmessage:
    ordv=ord(i)-n
    if(ordv<90):
        ordv+=26
    elif(ordv<65):
        ordv=ordv+26
    chart=chr(ordv)

# %%
s="b1 is best"
print(s.split(" ",1))
# Out:
# ['b1', 'is best']

# %%
s="a vgha a gh a"
s.split("a",2)
# Out:
# ['', ' vgh', ' a gh a']

# %%
str=input("Enter string")
newstr=""
for i in  str.split():
    i=i.capitalize()
    i=i[0:len(i)-1]+i[len(i)-1].upper()
    newstr=newstr+i+" "
print(newstr)
# Out:
# Enter stringabcd efgh
# AbcD EfgH

# %%
print("-".join(["1","Vishal","10"]))
# Out:
# 1-Vishal-10

# %%
s="vha is good,b1 is good"
print(s.replace("good","best",1))
# Out:
# vha is best,b1 is good

# %%
bhavya=""
table=bhavya.maketrans("abc","def","i")
print(table)
s="avis blac"
print(s.translate(table))
# Out:
# {97: 100, 98: 101, 99: 102, 105: None}
# dvs eldf

# %%
import string
l=string.punctuation
str=input("Enter string")
table="".maketrans("","",l)
str=str.translate(table)
print(str)
# Out:
# Enter stringabcd??__jhfu
# abcdjhfu
