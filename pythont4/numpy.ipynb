# %%
import numpy as np
l=[1,2,3,4,5]
x=np.array(l)
print(x)
np.shape(x)#number of rows,number of columns
x.ndim#says 1/2/3
# Out:
# [1 2 3 4 5]
# 1

# %%
#np.sort(axis=1(default)/0)
for i in np.nditer(x): #no need for multiple loops to access values
    print(i)
x.shape#attribute of array 
y=x.reshape(5,1)
# Out:
# 1
# 2
# 3
# 4
# 5
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %%
import matplotlib.pyplot as plt

# %%
phase=["T1","T2","T3","T4"]
marks=[20,22,18.5,17]
plt.subplot(2,3,1)       
plt.plot(phase,marks,marker="v",ms=20,mec="yellow",mfc="green",color="blue",linestyle=":",linewidth=5)
f1={"family":"sans-serif","color":"red","fontsize":15}
f2={"family":"serif","color":"blue","fontsize":20}
f3={"family":"serif","color":"green","fontsize":25}
plt.xlabel("Phase",fontdict=f1)
plt.ylabel("Marks",fontdict=f2)
plt.title("Phase vs Marks",fontdict=f3)
plt.subplot(2,3,2)
plt.bar(phase,marks,color="red")
plt.show()
