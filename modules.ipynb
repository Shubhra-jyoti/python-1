# %%
from datetime import date,time,datetime
date.today()
datetime.now()
# Out:
# datetime.datetime(2025, 12, 2, 10, 46, 25, 801597)

# %%
import os
os.getcwd()
os.chdir("..")
os.getcwd()
# os.mkdir("D:/VHA")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-1-cf7d0c007827> in <module>
#       3 os.chdir("..")
#       4 os.getcwd()
# ----> 5 os.mkdir("D:/VHA")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'D:/VHA'

# %%
os.mkdir("D:/VHA/vha10")

# %%
os.chdir("D:/VHA/vha10")

# %%
os.getcwd()
# Out:
# 'D:\\VHA\\vha10'

# %%
os.listdir("c:")
# Out:
# ['!qhlogs.doc',
#  '$Recycle.Bin',
#  '$WinREAgent',
#  'cfrbackup-ILUFYVFA',
#  'Config.Msi',
#  'DEMO',
#  'Documents and Settings',
#  'DumpStack.log.tmp',
#  'eula.1028.txt',
#  'eula.1031.txt',
#  'eula.1033.txt',
#  'eula.1036.txt',
#  'eula.1040.txt',
#  'eula.1041.txt',
#  'eula.1042.txt',
#  'eula.2052.txt',
#  'eula.3082.txt',
#  'globdata.ini',
#  'hiberfil.sys',
#  'inetpub',
#  'Insight Files',
#  'install.exe',
#  'install.ini',
#  'install.res.1028.dll',
#  'install.res.1031.dll',
#  'install.res.1033.dll',
#  'install.res.1036.dll',
#  'install.res.1040.dll',
#  'install.res.1041.dll',
#  'install.res.1042.dll',
#  'install.res.2052.dll',
#  'install.res.3082.dll',
#  'Intel',
#  'logs',
#  'msdia80.dll',
#  'MSOCache',
#  'oraclexe',
#  'pagefile.sys',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'ProgramData',
#  'Recovery',
#  'RESULT',
#  'swapfile.sys',
#  'System Volume Information',
#  'TempVerification',
#  'TurboC++',
#  'Users',
# ...

# %%
os.listdir("d:")
# Out:
# ['$RECYCLE.BIN',
#  'FSD-1',
#  'pythont3',
#  'System Volume Information',
#  't3_fsd_b2',
#  'VHA']

# %%
f1=open("file1.txt","w")
f2=open("file2.txt","w")
f1.write("hello")
f2.write("hello")
f1.close()
f2.close()

# %%
os.listdir("D:/VHA/vha10")
# Out:
# ['file1.txt', 'file2.txt']

# %%
# os.remove("d:/VHA/vha10/file1.txt") run only one time
import os
# os.rmdir("D:/VHA/vha10") remove folder 
# os.chdir("d:/pythont3")
# os.rmdir("d:/VHA")
os.getcwd()
# Out:
# 'd:\\pythont3'

# %%
# %%writefile calc.py
def add(a,b):
    return a+b
def mul(a,b):
    return a*b
def subtract(a,b):
    if(a>b):
        return a-b
    else:
        return b-a
def divide(a,b):
    if(b!=0):
        return a/b
    else:
        return "division by zero not possible"
# Out:
# Overwriting calc.py

# %%
import calc as c
print(c.add(3,5))
print(c.divide(5,2))
c.subtract(4,7)
# Out:
# 8
# 2.5
# 3

# %%
from calc import *

add(3,5)
subtract(3,5)
# Out:
# 2

# %%
# %%writefile B1.py
def find(string,target):
    x=len(target)
    if(target not in string ):
        return -1
    else:
        found=False
        for i,j in enumerate(string):
            start=i
            sub=string[start:start+x]
            if(target==sub):
                found=True
                return i
        if(not found):
            return -1
def rfind(string,target):
    ans=-1
    x=len(target)
    if(target not in string):
        return -1
    else:
        found=False
        for i,j in enumerate(string):
            start=i
            sub=string[start:start+i]
            if(sub==target):
                ans=i
                found=True
        if(not found):
            return -1
        else:
            return ans
def count(string,target):
    count=0
    x=len(target)
    for i,j in enumerate(string):
        if(string[i:i+x]==target):
            count+=1
    return count
def first(string):
    if(string==""):
        return "invalid"
    else:
        return(string[0])
# Out:
# Writing B1.py

# %%
# print("hi"
# Out:
#   File "<ipython-input-14-570e809efe38>", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing
